# %% [markdown]
# ## Teach a Multilayer Perceptron Model to do Addition
#
# All code created here followed a "Sound of AI" tutorial [here](https://www.youtube.com/watch?v=JdXxaZcQer8&list=PL-wATfeyAMNrtbkCNsLcpoAyBBRJZVlnf&index=9).

# %%
import numpy as np
from random import random
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
#----Goal-----

#Create MultiLayer Perceptron model that learns how to do addition

#----Gameplan----

#create dataset
#build model
#compile model
#train model
#evaluate model
#make predictions

# %%
def generate_dataset(num_samples, testsize=0.33):
  """Generate train/test data for sum operation

  :param num_samples (int): Num of total samples in dataset
  :param test_size (float): Ratio of num_samples used as test set
  :return x_train (ndarray): 2d array with input data for training
  :return x_test (ndarray): 2d array with input data for testing
  :return y_train (ndarray): 2d array with target data for training
  :return y_test (ndarray): 2d array with target data for testing
  """

  # build inputs/targets for sum operation: y[0][0] = x[0][0] + x[0][1]
  x = np.array([[random()/2 for _ in range(2)] for _ in range(num_samples)])
  y = np.array([ [ i[0]+i[1] ]  for i in x])

  # split dataset into test and training sets
  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=testsize)
  return x_train, x_test, y_train, y_test

# %%
if __name__ == "__main__":

  #create dataset with 5000 samples
  generate_dataset(5000)

  #build model with 3 layers: 2 (input) -> 5 (hidden) -> 1 (output)

  #keras = high level library that makes tf easy to use
  #sequential = signal in our network moves from left to right
  #Dense = all neurons are connected to each other

  model = tf.keras.Sequential([
             tf.keras.layers.Dense(5, input_dim=2, activation="sigmoid"),
             tf.keras.layers.Dense(1, activation="sigmoid")     
  ])

  #choose optimizer
  optimizer = tf.keras.optimizers.SGD(learning_rate=0.1) #SGD=Stochastic Gradient Descent

  #compile model
  model.compile(optimizer=optimizer, loss="MSE") #MSE=Mean squared error

  #train model
  model.fit(x_train, y_train, epochs=200)

  #evaluate model on test set
  print("\n Evaluate model on test set:")
  model.evaluate(x_test, y_test, verbose=1) #verbose prints things out

  #make predictions
  data = np.array([[0.1, 0.2], [0.2, 0.2]]) #excpet np.array([[0.3], [0.4]])
  predictions = model.predict(data)

  #print predictions
  print("\nSome predictions:")
  for d, p in zip(data, predictions): #d=data, p=predictions
    print("{} + {} = {}".format(d[0], d[1], p[0]))
# Out:
# Epoch 1/200
# 110/110 [==============================] - 0s 837us/step - loss: 0.0435
# Epoch 2/200
# 110/110 [==============================] - 0s 792us/step - loss: 0.0428
# Epoch 3/200
# 110/110 [==============================] - 0s 767us/step - loss: 0.0424
# Epoch 4/200
# 110/110 [==============================] - 0s 755us/step - loss: 0.0419
# Epoch 5/200
# 110/110 [==============================] - 0s 782us/step - loss: 0.0415
# Epoch 6/200
# 110/110 [==============================] - 0s 752us/step - loss: 0.0410
# Epoch 7/200
# 110/110 [==============================] - 0s 740us/step - loss: 0.0407
# Epoch 8/200
# 110/110 [==============================] - 0s 819us/step - loss: 0.0402
# Epoch 9/200
# 110/110 [==============================] - 0s 842us/step - loss: 0.0398
# Epoch 10/200
# 110/110 [==============================] - 0s 762us/step - loss: 0.0393
# Epoch 11/200
# 110/110 [==============================] - 0s 765us/step - loss: 0.0388
# Epoch 12/200
# 110/110 [==============================] - 0s 789us/step - loss: 0.0383
# Epoch 13/200
# 110/110 [==============================] - 0s 784us/step - loss: 0.0378
# Epoch 14/200
# 110/110 [==============================] - 0s 776us/step - loss: 0.0373
# Epoch 15/200
# 110/110 [==============================] - 0s 776us/step - loss: 0.0368
# Epoch 16/200
# 110/110 [==============================] - 0s 775us/step - loss: 0.0362
# Epoch 17/200
# 110/110 [==============================] - 0s 761us/step - loss: 0.0356
# Epoch 18/200
# 110/110 [==============================] - 0s 743us/step - loss: 0.0350
# Epoch 19/200
# 110/110 [==============================] - 0s 832us/step - loss: 0.0344
# Epoch 20/200
# 110/110 [==============================] - 0s 749us/step - loss: 0.0338
# Epoch 21/200
# 110/110 [==============================] - 0s 749us/step - loss: 0.0331
# Epoch 22/200
# 110/110 [==============================] - 0s 746us/step - loss: 0.0324
# Epoch 23/200
# 110/110 [==============================] - 0s 784us/step - loss: 0.0317
# Epoch 24/200
# 110/110 [==============================] - 0s 745us/step - loss: 0.0310
# Epoch 25/200
# 110/110 [==============================] - 0s 753us/step - loss: 0.0302
# Epoch 26/200
# 110/110 [==============================] - 0s 800us/step - loss: 0.0294
# Epoch 27/200
# 110/110 [==============================] - 0s 830us/step - loss: 0.0286
# Epoch 28/200
# 110/110 [==============================] - 0s 853us/step - loss: 0.0278
# Epoch 29/200
# 110/110 [==============================] - 0s 886us/step - loss: 0.0270
# Epoch 30/200
# 110/110 [==============================] - 0s 907us/step - loss: 0.0262
# Epoch 31/200
# 110/110 [==============================] - 0s 856us/step - loss: 0.0253
# Epoch 32/200
# 110/110 [==============================] - 0s 892us/step - loss: 0.0244
# Epoch 33/200
# 110/110 [==============================] - 0s 787us/step - loss: 0.0236
# Epoch 34/200
# 110/110 [==============================] - 0s 780us/step - loss: 0.0227
# Epoch 35/200
# 110/110 [==============================] - 0s 901us/step - loss: 0.0218
# Epoch 36/200
# 110/110 [==============================] - 0s 878us/step - loss: 0.0209
# Epoch 37/200
# 110/110 [==============================] - 0s 764us/step - loss: 0.0200
# Epoch 38/200
# 110/110 [==============================] - 0s 759us/step - loss: 0.0192
# Epoch 39/200
# 110/110 [==============================] - 0s 798us/step - loss: 0.0183
# Epoch 40/200
# 110/110 [==============================] - 0s 763us/step - loss: 0.0175
# Epoch 41/200
# 110/110 [==============================] - 0s 831us/step - loss: 0.0166
# Epoch 42/200
# 110/110 [==============================] - 0s 768us/step - loss: 0.0158
# Epoch 43/200
# 110/110 [==============================] - 0s 778us/step - loss: 0.0150
# Epoch 44/200
# 110/110 [==============================] - 0s 771us/step - loss: 0.0142
# Epoch 45/200
# 110/110 [==============================] - 0s 779us/step - loss: 0.0135
# Epoch 46/200
# 110/110 [==============================] - 0s 809us/step - loss: 0.0127
# Epoch 47/200
# 110/110 [==============================] - 0s 804us/step - loss: 0.0120
# Epoch 48/200
# 110/110 [==============================] - 0s 775us/step - loss: 0.0113
# Epoch 49/200
# 110/110 [==============================] - 0s 870us/step - loss: 0.0107
# Epoch 50/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0101
# Epoch 51/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0095
# Epoch 52/200
# 110/110 [==============================] - 0s 868us/step - loss: 0.0089
# Epoch 53/200
# 110/110 [==============================] - 0s 781us/step - loss: 0.0083
# Epoch 54/200
# 110/110 [==============================] - 0s 782us/step - loss: 0.0078
# Epoch 55/200
# 110/110 [==============================] - 0s 788us/step - loss: 0.0073
# Epoch 56/200
# 110/110 [==============================] - 0s 764us/step - loss: 0.0069
# Epoch 57/200
# 110/110 [==============================] - 0s 798us/step - loss: 0.0064
# Epoch 58/200
# 110/110 [==============================] - 0s 782us/step - loss: 0.0060
# Epoch 59/200
# 110/110 [==============================] - 0s 787us/step - loss: 0.0056
# Epoch 60/200
# 110/110 [==============================] - 0s 782us/step - loss: 0.0053
# Epoch 61/200
# 110/110 [==============================] - 0s 804us/step - loss: 0.0049
# Epoch 62/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0046
# Epoch 63/200
# 110/110 [==============================] - 0s 869us/step - loss: 0.0043
# Epoch 64/200
# 110/110 [==============================] - 0s 796us/step - loss: 0.0040
# Epoch 65/200
# 110/110 [==============================] - 0s 751us/step - loss: 0.0038
# Epoch 66/200
# 110/110 [==============================] - 0s 763us/step - loss: 0.0035
# Epoch 67/200
# 110/110 [==============================] - 0s 793us/step - loss: 0.0033
# Epoch 68/200
# 110/110 [==============================] - 0s 795us/step - loss: 0.0031
# Epoch 69/200
# 110/110 [==============================] - 0s 854us/step - loss: 0.0029
# Epoch 70/200
# 110/110 [==============================] - 0s 885us/step - loss: 0.0027
# Epoch 71/200
# 110/110 [==============================] - 0s 881us/step - loss: 0.0026
# Epoch 72/200
# 110/110 [==============================] - 0s 912us/step - loss: 0.0024
# Epoch 73/200
# 110/110 [==============================] - 0s 827us/step - loss: 0.0023
# Epoch 74/200
# 110/110 [==============================] - 0s 795us/step - loss: 0.0021
# Epoch 75/200
# 110/110 [==============================] - 0s 883us/step - loss: 0.0020
# Epoch 76/200
# 110/110 [==============================] - 0s 813us/step - loss: 0.0019
# Epoch 77/200
# 110/110 [==============================] - 0s 776us/step - loss: 0.0018
# Epoch 78/200
# 110/110 [==============================] - 0s 793us/step - loss: 0.0017
# Epoch 79/200
# 110/110 [==============================] - 0s 786us/step - loss: 0.0016
# Epoch 80/200
# 110/110 [==============================] - 0s 784us/step - loss: 0.0015
# Epoch 81/200
# 110/110 [==============================] - 0s 844us/step - loss: 0.0014
# Epoch 82/200
# 110/110 [==============================] - 0s 800us/step - loss: 0.0013
# Epoch 83/200
# 110/110 [==============================] - 0s 806us/step - loss: 0.0013
# Epoch 84/200
# 110/110 [==============================] - 0s 817us/step - loss: 0.0012
# Epoch 85/200
# 110/110 [==============================] - 0s 814us/step - loss: 0.0011
# Epoch 86/200
# 110/110 [==============================] - 0s 793us/step - loss: 0.0011
# Epoch 87/200
# 110/110 [==============================] - 0s 777us/step - loss: 0.0010
# Epoch 88/200
# 110/110 [==============================] - 0s 797us/step - loss: 9.8676e-04
# Epoch 89/200
# 110/110 [==============================] - 0s 767us/step - loss: 9.4267e-04
# Epoch 90/200
# 110/110 [==============================] - 0s 766us/step - loss: 9.0192e-04
# Epoch 91/200
# 110/110 [==============================] - 0s 809us/step - loss: 8.6439e-04
# Epoch 92/200
# 110/110 [==============================] - 0s 764us/step - loss: 8.2982e-04
# Epoch 93/200
# 110/110 [==============================] - 0s 755us/step - loss: 7.9768e-04
# Epoch 94/200
# 110/110 [==============================] - 0s 806us/step - loss: 7.6750e-04
# Epoch 95/200
# 110/110 [==============================] - 0s 873us/step - loss: 7.3985e-04
# Epoch 96/200
# 110/110 [==============================] - 0s 756us/step - loss: 7.1420e-04
# Epoch 97/200
# 110/110 [==============================] - 0s 778us/step - loss: 6.9039e-04
# Epoch 98/200
# 110/110 [==============================] - 0s 787us/step - loss: 6.6849e-04
# Epoch 99/200
# 110/110 [==============================] - 0s 806us/step - loss: 6.4800e-04
# Epoch 100/200
# 110/110 [==============================] - 0s 799us/step - loss: 6.2896e-04
# Epoch 101/200
# 110/110 [==============================] - 0s 884us/step - loss: 6.1107e-04
# Epoch 102/200
# 110/110 [==============================] - 0s 1ms/step - loss: 5.9503e-04
# Epoch 103/200
# 110/110 [==============================] - 0s 905us/step - loss: 5.7988e-04
# Epoch 104/200
# 110/110 [==============================] - 0s 855us/step - loss: 5.6579e-04
# Epoch 105/200
# 110/110 [==============================] - 0s 802us/step - loss: 5.5282e-04
# Epoch 106/200
# 110/110 [==============================] - 0s 768us/step - loss: 5.4095e-04
# Epoch 107/200
# 110/110 [==============================] - 0s 833us/step - loss: 5.2980e-04
# Epoch 108/200
# 110/110 [==============================] - 0s 838us/step - loss: 5.1921e-04
# Epoch 109/200
# 110/110 [==============================] - 0s 762us/step - loss: 5.0977e-04
# Epoch 110/200
# 110/110 [==============================] - 0s 850us/step - loss: 5.0094e-04
# Epoch 111/200
# 110/110 [==============================] - 0s 785us/step - loss: 4.9264e-04
# Epoch 112/200
# 110/110 [==============================] - 0s 882us/step - loss: 4.8511e-04
# Epoch 113/200
# 110/110 [==============================] - 0s 765us/step - loss: 4.7792e-04
# Epoch 114/200
# 110/110 [==============================] - 0s 790us/step - loss: 4.7150e-04
# Epoch 115/200
# 110/110 [==============================] - 0s 867us/step - loss: 4.6533e-04
# Epoch 116/200
# 110/110 [==============================] - 0s 788us/step - loss: 4.5977e-04
# Epoch 117/200
# 110/110 [==============================] - 0s 826us/step - loss: 4.5449e-04
# Epoch 118/200
# 110/110 [==============================] - 0s 885us/step - loss: 4.4973e-04
# Epoch 119/200
# 110/110 [==============================] - 0s 783us/step - loss: 4.4518e-04
# Epoch 120/200
# 110/110 [==============================] - 0s 806us/step - loss: 4.4090e-04
# Epoch 121/200
# 110/110 [==============================] - 0s 893us/step - loss: 4.3716e-04
# Epoch 122/200
# 110/110 [==============================] - 0s 915us/step - loss: 4.3352e-04
# Epoch 123/200
# 110/110 [==============================] - 0s 868us/step - loss: 4.3017e-04
# Epoch 124/200
# 110/110 [==============================] - 0s 955us/step - loss: 4.2706e-04
# Epoch 125/200
# 110/110 [==============================] - 0s 962us/step - loss: 4.2415e-04
# Epoch 126/200
# 110/110 [==============================] - 0s 783us/step - loss: 4.2150e-04
# Epoch 127/200
# 110/110 [==============================] - 0s 868us/step - loss: 4.1900e-04
# Epoch 128/200
# 110/110 [==============================] - 0s 911us/step - loss: 4.1673e-04
# Epoch 129/200
# 110/110 [==============================] - 0s 973us/step - loss: 4.1449e-04
# Epoch 130/200
# 110/110 [==============================] - 0s 836us/step - loss: 4.1253e-04
# Epoch 131/200
# 110/110 [==============================] - 0s 808us/step - loss: 4.1051e-04
# Epoch 132/200
# 110/110 [==============================] - 0s 870us/step - loss: 4.0893e-04
# Epoch 133/200
# 110/110 [==============================] - 0s 865us/step - loss: 4.0726e-04
# Epoch 134/200
# 110/110 [==============================] - 0s 900us/step - loss: 4.0567e-04
# Epoch 135/200
# 110/110 [==============================] - 0s 1ms/step - loss: 4.0437e-04
# Epoch 136/200
# 110/110 [==============================] - 0s 781us/step - loss: 4.0305e-04
# Epoch 137/200
# 110/110 [==============================] - 0s 838us/step - loss: 4.0184e-04
# Epoch 138/200
# 110/110 [==============================] - 0s 818us/step - loss: 4.0081e-04
# Epoch 139/200
# 110/110 [==============================] - 0s 776us/step - loss: 3.9966e-04
# Epoch 140/200
# 110/110 [==============================] - 0s 879us/step - loss: 3.9866e-04
# Epoch 141/200
# 110/110 [==============================] - 0s 844us/step - loss: 3.9781e-04
# Epoch 142/200
# 110/110 [==============================] - 0s 837us/step - loss: 3.9675e-04
# Epoch 143/200
# 110/110 [==============================] - 0s 798us/step - loss: 3.9616e-04
# Epoch 144/200
# 110/110 [==============================] - 0s 816us/step - loss: 3.9541e-04
# Epoch 145/200
# 110/110 [==============================] - 0s 848us/step - loss: 3.9455e-04
# Epoch 146/200
# 110/110 [==============================] - 0s 864us/step - loss: 3.9413e-04
# Epoch 147/200
# 110/110 [==============================] - 0s 813us/step - loss: 3.9346e-04
# Epoch 148/200
# 110/110 [==============================] - 0s 801us/step - loss: 3.9291e-04
# Epoch 149/200
# 110/110 [==============================] - 0s 829us/step - loss: 3.9236e-04
# Epoch 150/200
# 110/110 [==============================] - 0s 861us/step - loss: 3.9168e-04
# Epoch 151/200
# 110/110 [==============================] - 0s 794us/step - loss: 3.9139e-04
# Epoch 152/200
# 110/110 [==============================] - 0s 771us/step - loss: 3.9104e-04
# Epoch 153/200
# 110/110 [==============================] - 0s 777us/step - loss: 3.9049e-04
# Epoch 154/200
# 110/110 [==============================] - 0s 796us/step - loss: 3.9017e-04
# Epoch 155/200
# 110/110 [==============================] - 0s 836us/step - loss: 3.8981e-04
# Epoch 156/200
# 110/110 [==============================] - 0s 835us/step - loss: 3.8949e-04
# Epoch 157/200
# 110/110 [==============================] - 0s 850us/step - loss: 3.8915e-04
# Epoch 158/200
# 110/110 [==============================] - 0s 782us/step - loss: 3.8884e-04
# Epoch 159/200
# 110/110 [==============================] - 0s 878us/step - loss: 3.8860e-04
# Epoch 160/200
# 110/110 [==============================] - 0s 1ms/step - loss: 3.8829e-04
# Epoch 161/200
# 110/110 [==============================] - 0s 792us/step - loss: 3.8806e-04
# Epoch 162/200
# 110/110 [==============================] - 0s 783us/step - loss: 3.8778e-04
# Epoch 163/200
# 110/110 [==============================] - 0s 820us/step - loss: 3.8755e-04
# Epoch 164/200
# 110/110 [==============================] - 0s 901us/step - loss: 3.8738e-04
# Epoch 165/200
# 110/110 [==============================] - 0s 793us/step - loss: 3.8721e-04
# Epoch 166/200
# 110/110 [==============================] - 0s 880us/step - loss: 3.8692e-04
# Epoch 167/200
# 110/110 [==============================] - 0s 788us/step - loss: 3.8677e-04
# Epoch 168/200
# 110/110 [==============================] - 0s 1ms/step - loss: 3.8665e-04
# Epoch 169/200
# 110/110 [==============================] - 0s 808us/step - loss: 3.8648e-04
# Epoch 170/200
# 110/110 [==============================] - 0s 833us/step - loss: 3.8621e-04
# Epoch 171/200
# 110/110 [==============================] - 0s 829us/step - loss: 3.8599e-04
# Epoch 172/200
# 110/110 [==============================] - 0s 852us/step - loss: 3.8597e-04
# Epoch 173/200
# 110/110 [==============================] - 0s 852us/step - loss: 3.8579e-04
# Epoch 174/200
# 110/110 [==============================] - 0s 808us/step - loss: 3.8571e-04
# Epoch 175/200
# 110/110 [==============================] - 0s 788us/step - loss: 3.8534e-04
# Epoch 176/200
# 110/110 [==============================] - 0s 867us/step - loss: 3.8549e-04
# Epoch 177/200
# 110/110 [==============================] - 0s 809us/step - loss: 3.8543e-04
# Epoch 178/200
# 110/110 [==============================] - 0s 795us/step - loss: 3.8508e-04
# Epoch 179/200
# 110/110 [==============================] - 0s 802us/step - loss: 3.8505e-04
# Epoch 180/200
# 110/110 [==============================] - 0s 875us/step - loss: 3.8506e-04
# Epoch 181/200
# 110/110 [==============================] - 0s 793us/step - loss: 3.8481e-04
# Epoch 182/200
# 110/110 [==============================] - 0s 779us/step - loss: 3.8485e-04
# Epoch 183/200
# 110/110 [==============================] - 0s 851us/step - loss: 3.8472e-04
# Epoch 184/200
# 110/110 [==============================] - 0s 845us/step - loss: 3.8461e-04
# Epoch 185/200
# 110/110 [==============================] - 0s 803us/step - loss: 3.8450e-04
# Epoch 186/200
# 110/110 [==============================] - 0s 827us/step - loss: 3.8437e-04
# Epoch 187/200
# 110/110 [==============================] - 0s 915us/step - loss: 3.8434e-04
# Epoch 188/200
# 110/110 [==============================] - 0s 815us/step - loss: 3.8428e-04
# Epoch 189/200
# 110/110 [==============================] - 0s 790us/step - loss: 3.8421e-04
# Epoch 190/200
# 110/110 [==============================] - 0s 876us/step - loss: 3.8396e-04
# Epoch 191/200
# 110/110 [==============================] - 0s 816us/step - loss: 3.8400e-04
# Epoch 192/200
# 110/110 [==============================] - 0s 792us/step - loss: 3.8396e-04
# Epoch 193/200
# 110/110 [==============================] - 0s 1ms/step - loss: 3.8379e-04
# Epoch 194/200
# 110/110 [==============================] - 0s 836us/step - loss: 3.8371e-04
# Epoch 195/200
# 110/110 [==============================] - 0s 813us/step - loss: 3.8380e-04
# Epoch 196/200
# 110/110 [==============================] - 0s 775us/step - loss: 3.8364e-04
# Epoch 197/200
# 110/110 [==============================] - 0s 1ms/step - loss: 3.8356e-04
# Epoch 198/200
# 110/110 [==============================] - 0s 801us/step - loss: 3.8349e-04
# Epoch 199/200
# 110/110 [==============================] - 0s 828us/step - loss: 3.8333e-04
# Epoch 200/200
# 110/110 [==============================] - 0s 906us/step - loss: 3.8339e-04
#
#  Evaluate model on test set:
# 47/47 [==============================] - 0s 724us/step - loss: 4.3939e-04
#
# Some predictions:
# 0.1 + 0.2 = 0.283980131149292
# 0.2 + 0.2 = 0.3896086513996124
